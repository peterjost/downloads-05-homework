# %% [markdown]
# # Homework 14, Mapping Part 2

# %%
import pandas as pd
import geopandas as gpd

# %%
from shapely.geometry import Point
from shapely.geometry import Polygon

# %%
# %matplotlib inline

# %% [markdown]
# ## Import data - US states

# %%
states = gpd.read_file('cb_2016_us_state_500k/cb_2016_us_state_500k.shp')
states.shape
# Out:
# (56, 10)

# %%
states.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
usa = states.to_crs({'init': 'epsg:4326'})
bounds = [
    [-128.144531,50.346395],
    [-63.105469,50.346395],
    [-63.105469,23.244037],
    [-128.144531,23.244037],
]
usa_bounds = Polygon(bounds)
usa = usa[usa.within(usa_bounds)]
usa.plot()

# %% [markdown]
# ## Import data - powerplants

# %%
df = pd.read_csv('powerplants.csv')
df.shape
# Out:
# (7610, 28)

# %%
df.head(3)
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
#
#          sector_nam       City      County    Zip            Street_Add  \
# 0  Electric Utility  Northport  Tuscaloosa  35476    19001 Lock 17 Road
# 1  Electric Utility      Bucks      Mobile  36512      North Highway 43
# 2  Electric Utility   Wetumpka      Elmore  36092  750 Bouldin Dam Road
#
#       PrimSource    ...      Solar_MW  Wind_MW  Geo_MW  Other_MW  \
# 0  hydroelectric    ...           0.0      0.0     NaN       NaN
# 1           coal    ...           0.0      0.0     NaN       NaN
# 2  hydroelectric    ...           0.0      0.0     NaN       NaN
#
#                                 source_des  \
# 0                    Hydroelectric = 56 MW
# 1  Coal = 1088.5 MW, Natural Gas = 1072 MW
# ...

# %%
df['geometry'] = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
powerplants = gpd.GeoDataFrame(df, geometry='geometry')
powerplants.crs = {'init': 'epsg:4326'}
powerplants = powerplants[powerplants.within(USA_bounds)]
powerplants.plot()

# %% [markdown]
# ## Import data - air quality

# %%
df = pd.read_csv('pm25_annual_fixed.csv')
df.shape
# Out:
# (441, 55)

# %%
df['geometry'] = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
pm25stations = gpd.GeoDataFrame(df, geometry='geometry')
pm25stations.crs = {'init': 'epsg:4326'}
pm25stations = pm25stations[pm25stations.within(USA_bounds)]

# %%
pm25stations.plot()

# %% [markdown]
# # Questions / Answers

# %% [markdown]
# 1) Make a map of power plants in the US, color coded by type

# %%
powerplants.PrimSource.value_counts()
# Out:
# natural gas       1661
# solar             1368
# hydroelectric     1366
# wind               921
# biomass            734
# petroleum          724
# coal               375
# other              109
# geothermal          65
# nuclear             62
# pumped storage      34
# Name: PrimSource, dtype: int64

# %%
ax = states.plot(color='lightgrey', edgecolor='white', figsize=(14,14))
powerplants.plot(ax=ax, column='PrimSource', cmap='tab10', legend=True)

# %% [markdown]
# 2) Make a map of air quality stations, color coded by average air quality

# %%
pd.set_option("display.max_columns", 100) 
pm25stations.head(2)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           88101    1  30.497478
# 1           1           27         1           88101    1  33.284928
#
#    Longitude  Datum            Parameter Name Sample Duration  \
# 0 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR
# 1 -85.803608  NAD83  PM2.5 - Local Conditions         24 HOUR
#
#   Pollutant Standard Metric Used  \
# 0  PM25 24-hour 2012  Daily Mean
# 1  PM25 24-hour 2012  Daily Mean
#
#                                          Method Name  Year  \
# 0  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017
# 1  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2017
#
#               Units of Measure Event Type  Observation Count  \
# 0  Micrograms/cubic meter (LC)  No Events                 28
# 1  Micrograms/cubic meter (LC)  No Events                 27
#
#    Observation Percent Completeness Indicator  Valid Day Count  \
# ...

# %%
ax = states.plot(color='lightgray', edgecolor='white', figsize=(14,14))
ax = pm25stations.plot(ax=ax, column='Arithmetic Mean', cmap='Greens', scheme='equal_interval', markersize=10, alpha=0.6, legend=True)
ax.set_title("Average levels of PM25")

# %% [markdown]
# 3) Make a map of air quality stations, color coded by worst air quality ever

# %%
ax = states.plot(color='lightgray', edgecolor='white', figsize=(14,14))
ax = pm25stations.plot(ax=ax, column='1st Max Value', cmap='Reds', scheme='equal_interval', markersize=10, alpha=0.6, legend=True)
ax.set_title("Average levels of PM25")
