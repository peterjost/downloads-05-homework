# %% [markdown]
# # Exercise: NEISS, Question Set C
#
# #### Summary
#
# The [National Electronic Injury Surveillance System](https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS) is a data product produced by the US Consumer Product Safety Commission. It tracks emergency room injuries related to consumer products (e.g., "a door fell on me!").
#
# #### Files
#
# - **nss15.tsv**: injury data (one injury per row)
# - **2017NEISSCodingManualCPSConlyNontrauma.pdf**: column definitions and explanations
# - **2015 Neiss data highlights.pdf**: a partial summary of the data
# - **2017ComparabilityTable.pdf**: product code definitions
# - **categories-cleaned.txt**: product code definitions in CSV format (great for joining!)
#
# #### Source
#
# https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS
#
# #### Skills
#
# - Reading tab-separated files
# - Ignoring bad lines
# - Replacing values
# - Using numpy/`np.nan`
# - String search using regular expressions
# - Averages practice
# - Converting `.value_counts()` and similar results into DataFrames

# %% [markdown]
# # Read in `nss15.tsv`
#
# Some of the lines just **aren't formatted correctly**. Maybe we can avoid those?

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("nss15.tsv", sep="\t", error_bad_lines=False)
# Out:
# b'Skipping line 10822: expected 19 fields, saw 20\n'
# b'Skipping line 48623: expected 19 fields, saw 20\nSkipping line 62534: expected 19 fields, saw 20\n'
# b'Skipping line 103739: expected 19 fields, saw 20\n'
# b'Skipping line 135495: expected 19 fields, saw 20\nSkipping line 151678: expected 19 fields, saw 20\n'
# b'Skipping line 237135: expected 19 fields, saw 20\nSkipping line 240597: expected 19 fields, saw 20\n'
# b'Skipping line 274270: expected 19 fields, saw 20\nSkipping line 277461: expected 19 fields, saw 20\n'

# %% [markdown]
# ### Check that your dataframe has 357727 rows and 19 columns.

# %%
df.shape
# Out:
# (357727, 19)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes
# Out:
# CPSC Case #      int64
# trmt_date       object
# psu              int64
# weight         float64
# stratum         object
# age              int64
# sex              int64
# race             int64
# race_other      object
# diag             int64
# diag_other      object
# body_part        int64
# disposition      int64
# location         int64
# fmv              int64
# prod1            int64
# prod2          float64
# narr1           object
# narr2           object
# dtype: object

# %% [markdown]
# ### What does each column mean?

# %%
#CPSC Case #      int64 - case number
#trmt_date       object - treatment date
#psu              int64 - Primary Sampling Unit (statistical info relating to the SUDAAN model)
#weight         float64 - Weight (statistical info relating to the SUDAAN model)
#stratum         object - Stratum (statistical info relating to the SUDAAN model)
#age              int64 - Age
#sex              int64 - 1-digit-code for the Sex
#race             int64 - 1-digit-code for the race
#race_other      object - more info
#diag             int64 - 2-digit-code for the diagnose 
#diag_other      object - more info
#body_part        int64 - 4-digit-code for the affected body part
#disposition      int64 - 1-digit-code for the disposition (=result of the process)
#location         int64 - 1-digit-code for the location of the accident
#fmv              int64 - 1-digit-code wether fire was involved in accident
#prod1            int64 - 4-digit-code for objects involved in accident
#prod2          float64 - more info
#narr1           object - raw text describing the accident
#narr2           object - more info

# %% [markdown]
# # Cleaning up a column
#
# Take a look at the **sex** column. How many rows of each sex are there?

# %%
df.sex.value_counts()
# Out:
# 1    195071
# 2    162654
# 0         2
# Name: sex, dtype: int64

# %% [markdown]
# ## Replace the numbers with the appropriate words they stand for.
#
# Those numbers are terrible - codes are fine for storage but not really for reading. **Replace the numbers with the  words they stand for.**
#
# Refer to page 7 of the column definitions file.

# %%
df.sex.replace(2, "Female", inplace=True)

# %%
df.sex.replace(1, "Male", inplace=True)

# %%
df.sex.replace(0, "Unknown", inplace=True)

# %% [markdown]
# ## Confirm you have 195071 male, 162654 female, and 2 "Not Recorded."

# %%
df.sex.value_counts()
# Out:
# Male       195071
# Female     162654
# Unknown         2
# Name: sex, dtype: int64

# %% [markdown]
# ## Graph the number of men and women, but don’t included the “Not Recorded” records

# %%
df[df.sex != "Unknown"].sex.value_counts().plot(kind="barh", figsize=(10,3))

# %% [markdown]
# ## "Not recorded" seems silly - change it to be `NaN` instead
#
# Don't use `na_values` for this.

# %%
df.sex.replace("Unknown", np.nan, inplace=True)

# %% [markdown]
# ## Graph the count of men and women, but don’t included the “Not Recorded” records
#
# Yes, again! The code you use should be different this time.

# %%
df.sex.value_counts().plot(kind="barh", figsize=(10,3))

# %% [markdown]
# # Wall punching

# %% [markdown]
# ## Find every instance where the narrative includes punching a wall
#
# Include phrases like "punched a wall" or "punch wall" or "punched ten thousand walls." Do not type them each individually. How do you do that?????

# %%
df_wallpunchers = df[df.narr1.str.match(r".*punch.*wall.*", case=False)]
df_wallpunchers
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  age     sex  race  \
# 246       150532226  05/07/2015   63  97.9239       M   38    Male     0
# 582       150954076  09/16/2015   22  15.7762       V   13    Male     1
# 604       150541260  04/09/2015   53  15.0591       V   22    Male     1
# 704       151017458  10/05/2015   61  16.5650       V   15  Female     1
# 741       150433154  04/02/2015   91  15.0591       V   33    Male     1
# 782       150805902  07/22/2015    3  74.8813       L   28    Male     0
# 1098      150455805  03/27/2015   93  15.0591       V   25  Female     1
# 1571      150519707  04/21/2015   77  15.0591       V   14    Male     0
# 1616      151112964  09/21/2015   26  15.7762       V   16    Male     2
# 1660      150446653  04/14/2015   33  15.0591       V   52    Male     1
# 1707      160113449  12/22/2015   68  97.9239       M   20  Female     1
# 2064      150347487  03/15/2015   44  74.8813       L   26    Male     1
# 2669      150663851  06/13/2015  101  97.9239       M   22  Female     0
# 2714      150255182  02/25/2015   58  15.7762       V   13    Male     0
# 2953      150834668  08/12/2015   78  97.9239       M   24    Male     2
# 3126      151114759  10/05/2015   90   5.6748       C   17    Male     1
# 3150      151036494  10/10/2015   91  16.5650       V   18  Female     3
# 3260      150452382  04/19/2015   51  74.8813       L   21    Male     2
# 3714      150809087  06/09/2015   23  15.7762       V   20  Female     0
# 3794      150717882  07/04/2015    7  83.2157       S   20    Male     0
# 3820      151036567  10/09/2015   51  74.8813       L   39    Male     1
# 4019      151006820  10/02/2015   21  16.5650       V   15  Female     0
# 4305      150458204  04/23/2015    8   5.6748       C   16    Male     1
# 4646      150727133  07/08/2015   51  74.8813       L   16    Male     1
# 4734      150828645  07/21/2015   54  49.2646       M   15    Male     1
# 4825      150739139  07/11/2015   37   5.6748       C   16  Female     0
# 3714          NaN    57            NaN         82            1         0    0
# 3794          NaN    57            NaN         82            1         0    0
# 3820          NaN    53            NaN         82            6         0    0
# 4019          NaN    71           PAIN         82            1         8    0
# 4305          NaN    57            NaN         82            1         0    0
# 4646          NaN    71  PAIN SWELLING         82            2         5    0
# 4734          NaN    71             NS         87            1         1    0
# 4825          NaN    57            NaN         82            1         0    0
# 4856          NaN    57            NaN         82            1         1    0
# 4910          NaN    53            NaN         82            1         0    0
# 4927          NaN    53            NaN         82            1         1    0
# 5057          NaN    57            NaN         82            1         5    0
# ...           ...   ...            ...        ...          ...       ...  ...
# 352195        NaN    57            NaN         82            1         5    0
# 352414        NaN    57            NaN         82            1         1    0
# 352646        NaN    53            NaN         82            1         8    0
# 352716        NaN    71           PAIN         82            1         0    0
# 352767   HISPANIC    57            NaN         82            1         0    0
# 353101        NaN    53            NaN         82            1         0    0
# 353627        NaN    64            NaN         82            1         1    0
# 353694        NaN    57            NaN         82            1         1    0
# 353864        NaN    53            NaN         82            1         1    0
# 353867        NaN    57            NaN         82            1         0    0
# 354002        NaN    71      HAND PAIN         82            1         1    0
# 354321        NaN    64            NaN         34            1         0    0
# 354324        NaN    53            NaN         82            1         1    0
# 354377        NaN    57            NaN         82            1         0    0
# 354598        NaN    71           PAIN         82            1         0    0
# 354673        NaN    53            NaN         82            1         0    0
# 355252        NaN    57            NaN         82            1         0    0
# 355335        NaN    57            NaN         82            1         0    0
# 355336        NaN    53            NaN         82            1         1    0
# 355570        NaN    71      HAND PAIN         82            1         0    0
# 355659        NaN    53            NaN         82            1         0    0
# 355761        NaN    57            NaN         82            1         1    0
# 356073        NaN    53            NaN         82            1         0    0
# 356137        NaN    53            NaN         82            1         1    0
# 356390        NaN    71           PAIN         82            1         0    0
# 356484        NaN    57            NaN         82            1         0    0
# 356975        NaN    57            NaN         82            1         1    0
# 356995        NaN    53            NaN         82            1         0    0
# 357305        NaN    53            NaN         82            1         1    0
# 357412        NaN    71           PAIN         82            1         1    0
#
#         prod1   prod2                                              narr1  \
# 246      1884     NaN                38YOM PUNCHED A WALL FRACTURED HAND
# 582      1884     NaN  PT PUNCHED A WALL. FRACTURE METACARPAL, RIGHT,...
# 604      1884     NaN  22YOM-HAND INJURY-PUNCHED A CEMENT WALL IN ANG...
# 704      1884     NaN  15 YOF C/O RIGHT HAND PAIN SINCE PUNCHING A WA...
# 741      1884     NaN  33YOM PUNCHED A WALL X1 WEEK AGO W/ SHARP PAIN...
# 782      1884     NaN               28YOM PUNCHED A WALL AND INJ RT HAND
# 1098     1884     NaN                             25 YOF PUNCHED A WALL.
# 1571     1884     NaN      14YOM SUST FX TO HAND WHEN HE PUNCHED A WALL*
# 1616     1884     NaN     16 YOM CONTUSION TO HAND AFTER PUNCHING A WALL
# 1660     1884     NaN         52 YOM PUNCHED WALL L HAND  DX:  FX 5TH MC
# 1707     1884     NaN  20 YOF PUNCHED A WALL SEVERAL WEEKS AGO. NOW H...
# 2064     1884     NaN  26 YOM PUNCHED WALL WITH BOTH HANDS DX CLINCHE...
# 2669     1884     NaN  22YOF PUNCHED A WALL WITH RIGHT HAND, RIGHT HA...
# 355570   1884     NaN  18 YOM DX HAND PAIN/INJURY - S/P PT PUNCHED A ...
# 355659   1884     NaN  25YOM ANGRY AND PUNCHED A WALL SUSTAINED AN AB...
# 355761   1884  1893.0  18YOM PUNCHED A WALL OR DOOR WHEN ANGRY LAST N...
# 356073   1884     NaN                               29YOF PUNCHED A WALL
# 356137   1807  1884.0  24YOM PT COMPLAINING OF PUNCHING A WALL AFTER ...
# 356390   1884     NaN  21YOM W/HAND PAIN 2/2 PUNCHING A CONCRETE WALL...
# 356484   1884     NaN                  34 YOM PUNCHED A WALL 7 DAYS AGO.
# 356975   1884     NaN       HAND FX.  29YOM PUNCHED WALL AND BROKE HAND.
# 356995   1884     NaN  21YOM PAIN TO R HAND WHEN PUNCHED A WALL. DX H...
# 357305   1884     NaN       RIGHT HAND CONTUSION. 16 YOF PUNCHED A WALL.
# 357412   1207  1884.0  28YOM WAS HITTING PUNCHING BAG AND MISSED HITT...
#
#                                                     narr2
# 246                                                   NaN
# 582                                                   NaN
# 604                                                   NaN
# 704                                 DX: CONTUSION OF HAND
# 741     DX: ACUTE CLOSED FX OF FIFTH METACARPAL, BOXER...
# 782                                                   NaN
# 1098                                    DX:  R HAND CONT.
# 1571                                                  NaN
# 1616                                                  NaN
# 1660                                                  NaN
# 1707                PAINFUL SOMETIMES. DX LEFT THUMB PAIN
# 2064                                                  NaN
# 2669                                                  NaN
# 2714                                        DX   FRACTURE
# 2953                                                 HAND
# 3126                      DX; RT 4TH METACARPAL CONTUSION
# 3150                                MPER DX: R HAND CONTU
# 3260                                       O DX HAND CONT
# 3714                                                    B
# 3794                                                  NaN
# 3820                                            HAND CONT
# 4019                                          >>HAND PAIN
# 4305                                                  NaN
# 4646    LITY BECAME AGGRESSIVE AND AGITATED DX MOOD D/...
# 4734    ENED TO KILL PARENTS/SELF   DX: ADHD, OPPOSITI...
# 4825                                  NT DX: FX TO R HAND
# 4856                                                  NaN
# 4910                                        DX  CONTUSION
# 4927                                                  NaN
# 5057                                                 >>FX
# ...                                                   ...
# 352195                                                NaN
# 352414                                                NaN
# 352646                      AT SCHOOL. DX HAND CONTUSION%
# 352716                                             >>PAIN
# 352767                        DX:  R THIRD METACARPAL FX.
# 353101                                            >>CONTS
# 353627                                                NaN
# 353694                                                NaN
# 353864                                                NaN
# 353867                              HAND. DX: FX OF HAND.
# 354002                                                NaN
# 354321                                                NaN
# 354324                                                NaN
# 354377                                                NaN
# 354598                         VE IT LOOKED AT UNTIL NOW.
# 354673                                                NaN
# 355252                                                NaN
# 355335                                         IGHT HAND*
# 355336                                                NaN
# 355570                                                NaN
# 355659                                                NaN
# 355761                                                NaN
# 356073                                 DX: HAND CONTUSION
# 356137             HOME HAND CONTUISON DX HAND CONTUSION#
# 356390                                                NaN
# 356484                        DX:  FX R FIFTH METACARPAL.
# 356975                                                NaN
# 356995                                                NaN
# 357305                                                NaN
# 357412                                                NaN
#
# [1772 rows x 19 columns]

# %%
df_wallpunchers.shape
# Out:
# (1772, 19)

# %% [markdown]
# ## Graph the gender distribution of wall-punching.

# %%
df_wallpunchers.sex.value_counts().plot(kind="barh", figsize=(10,3))

# %% [markdown]
# ## Find the average age of a wall-puncher.
#
# Graph the distribution of the ages, too.

# %%
df_wallpunchers.age.mean()
# Out:
# 24.303611738148984

# %%
df_wallpunchers.age.value_counts().sort_index().plot(kind="bar", figsize=(12, 5))

# %% [markdown]
# # Which months are the most popular for wall punching?
#
# The month is hidden inside of the `trmt_date` column - you'll need to extract it. To check, January should have 27109 cases.

# %%
df_wallpunchers.trmt_date.str.extract(r"\b(\d{2})/").value_counts().sort_values(ascending=False)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# 09    175
# 06    170
# 10    162
# 05    162
# 04    156
# 03    151
# 11    145
# 12    142
# 07    134
# 01    132
# 08    131
# 02    112
# Name: trmt_date, dtype: int64

# %% [markdown]
# ## Graph the amount of wall punching in each month
#
# Having numbers on the x axis (1-12) is fine.

# %%
df_wallpunchers.trmt_date.str.extract(r"\b(\d{2})/").value_counts().sort_index().plot(kind="bar", figsize=(5,3))
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Sort the graph so that the months are in order from Jan-Dec (or 01-12)

# %%
# see above

# %% [markdown]
# ## What month is most common for air conditioner-related injuries?
#
# Use the product code, which you can find in `2017ComparabilityTable.pdf` or `categories-cleaned.txt`.

# %%
df[df.prod1 == 381].trmt_date.str.extract(r"\b(\d{2})/").value_counts().sort_index().plot(kind="bar")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Find what else people punched using the prod1 and prod2 columns.
#
# Look at the top 10 for each separately.

# %%
#incidents where punching was involved in the field "narr1"
df_objectpunchers1 = df[df.narr1.str.match(r".*punch.*", case=False)]

# %%
#incidents where punching was involved in the field "narr2"
df_objectpunchers2 = df[df.narr2.str.match(r".*punch.*", na=False, case=False)]

# %%
#join the two columns
df_objectpunchers_all = df_objectpunchers1.append(df_objectpunchers2)
df_objectpunchers_all
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  age     sex  race  \
# 10        150734952  07/04/2015   57  15.7762       V   20    Male     2
# 38        150508503  05/03/2015   21  15.0591       V   22    Male     0
# 149       150503749  04/02/2015   53  15.0591       V   13    Male     1
# 246       150532226  05/07/2015   63  97.9239       M   38    Male     0
# 385       150741367  07/16/2015   18   5.6748       C   14    Male     2
# 582       150954076  09/16/2015   22  15.7762       V   13    Male     1
# 604       150541260  04/09/2015   53  15.0591       V   22    Male     1
# 704       151017458  10/05/2015   61  16.5650       V   15  Female     1
# 707       150957633  09/20/2015   58  15.7762       V   20    Male     0
# 741       150433154  04/02/2015   91  15.0591       V   33    Male     1
# 778       150658215  06/24/2015   39  83.2157       S   27    Male     1
# 782       150805902  07/22/2015    3  74.8813       L   28    Male     0
# 947       150434622  04/07/2015    8   5.6748       C   15    Male     2
# 1015      151104320  09/03/2015   41  15.7762       V   22    Male     0
# 1098      150455805  03/27/2015   93  15.0591       V   25  Female     1
# 1571      150519707  04/21/2015   77  15.0591       V   14    Male     0
# 1616      151112964  09/21/2015   26  15.7762       V   16    Male     2
# 1660      150446653  04/14/2015   33  15.0591       V   52    Male     1
# 1707      160113449  12/22/2015   68  97.9239       M   20  Female     1
# 2064      150347487  03/15/2015   44  74.8813       L   26    Male     1
# 2527      150533500  04/27/2015   54  49.2646       M   67    Male     3
# 2669      150663851  06/13/2015  101  97.9239       M   22  Female     0
# 1571          NaN    57                   NaN         82            1
# 1616          NaN    53                   NaN         82            1
# 1660          NaN    57                   NaN         82            1
# 1707          NaN    71                  PAIN         92            1
# 2064          NaN    71                INJURY         82            1
# 2527     HISPANIC    57                   NaN         82            1
# 2669          NaN    64                   NaN         82            1
# 2714          NaN    57                   NaN         82            1
# 2777          NaN    59                   NaN         82            1
# 2953          NaN    55                   NaN         82            1
# 3038          NaN    71            WRIST PAIN         34            1
# 3126          NaN    53                   NaN         82            1
# 3150     HISPANIC    53                   NaN         82            1
# 3260          NaN    53                   NaN         82            1
# 3714          NaN    57                   NaN         82            1
# ...           ...   ...                   ...        ...          ...
# 294900        NaN    53                   NaN         82            1
# 300877        NaN    57                   NaN         82            1
# 301126        NaN    59                   NaN         82            1
# 305468        NaN    71  DEVIATED NASAL SEPTU         76            1
# 306924        NaN    57                   NaN         82            1
# 307102        NaN    53                   NaN         82            1
# 307147        NaN    59                   NaN         82            1
# 312376        NaN    57                   NaN         82            1
# 316649        NaN    53                   NaN         35            1
# 317395        NaN    59                   NaN         82            1
# 319242       HISP    53                   NaN         82            1
# 319770   HISPANIC    59                   NaN         82            1
# 320023        NaN    57                   NaN         82            1
# 321756        NaN    71                  PAIN         89            1
# 322976        NaN    53                   NaN         82            1
# 322983        NaN    57                   NaN         82            1
# 326175        NaN    53                   NaN         92            1
# 327492        NaN    57                   NaN         92            1
# 328904        NaN    53                   NaN         82            4
# 329009         NS    57                   NaN         76            1
# 335575        NaN    57                   NaN         92            1
# 336323        NaN    68                   NaN         85            1
# 338631        NaN    65                   NaN         85            4
# 342246        NaN    57                   NaN         76            1
# 343296        NaN    57                   NaN         80            1
# 343721        NaN    53                   NaN         82            1
# 347343        NaN    57                   NaN         34            1
# 349363   HISPANIC    53                   NaN         34            1
# 355892        NaN    71             DIZZINESS         75            6
# 357620        NaN    57                   NaN         92            1
#
#         location  fmv  prod1   prod2  \
# 10             1    0   1894     NaN
# 38             0    0   1893     NaN
# 149            0    0   1123     NaN
# 246            0    0   1884     NaN
# 385            1    0   1894     NaN
# 582            1    0   1884     NaN
# 604            1    0   1884     NaN
# 704            1    0   1884     NaN
# 707            1    0   1894     NaN
# 741            0    0   1884     NaN
# 778            1    0   1893     NaN
# 782            0    0   1884     NaN
# 947            8    0   1726     NaN
# 1015           0    0   4071     NaN
# 1098           0    0   1884     NaN
# 1571           0    0   1884     NaN
# 1616           5    0   1884     NaN
# 1660           1    0   1884     NaN
# 1707           1    0   1884     NaN
# 2064           1    0   1884     NaN
# 2527           1    0   4057     NaN
# 2669           1    0   1884     NaN
# 2714           1    0   1884     NaN
# 2777           1    0   1145     NaN
# 2953           1    0   1884     NaN
# 3038           1    0   4056     NaN
# 3126           5    0   1884     NaN
# 3150           0    0   1884     NaN
# 3260           0    0   1884     NaN
# 3714           0    0   1884     NaN
# ...          ...  ...    ...     ...
# 294900         1    0   1884  1893.0
# 300877         0    0   1893     NaN
# 301126         0    0   1894     NaN
# 305468         9    0   1207     NaN
# 306924         0    0   1884   550.0
# 307102         1    0   1894     NaN
# 307147         1    0   1894     NaN
# 312376         0    0   1871  1884.0
# 316649         4    0   5040     NaN
# 317395         8    0   1894     NaN
# 319242         1    0   1884     NaN
# 319770         1    0   1894     NaN
# 320023         0    0   1884     NaN
# 321756         0    0   1807     NaN
# 322976         0    0   1884     NaN
# 322983         9    0   1207     NaN
# 326175         1    0   1205  1884.0
# 327492         1    0   1884     NaN
# 328904         1    0   1884     NaN
# 329009         0    0   1207     NaN
# 335575         1    0    374   857.0
# 336323         1    0   4004     NaN
# 338631         1    3   1894     NaN
# 342246         0    0   1207     NaN
# 343296         1    0   1884     NaN
# 343721         0    0   1884     NaN
# 347343         1    0    276     NaN
# 349363         1    0   1894     NaN
# 355892         9    0   1207     NaN
# 357620         0    0   1726     NaN
#
#                                                     narr1  \
# 10      20 YOM DX HAND LACERATION - S/P PT PUNCHED A W...
# 38           22YM LHD, C/O RT HAND PAIN P PUNCHING A DOOR
# 149     13YOM-FOREARM LAC-PUNCHED A PLASTIC CONTAINER ...
# 246                   38YOM PUNCHED A WALL FRACTURED HAND
# 385     14 YOM THREW TANTRUM AND PUNCHED HAND THROUGH ...
# 582     PT PUNCHED A WALL. FRACTURE METACARPAL, RIGHT,...
# 604     22YOM-HAND INJURY-PUNCHED A CEMENT WALL IN ANG...
# 704     15 YOF C/O RIGHT HAND PAIN SINCE PUNCHING A WA...
# 707     20 YOM WAS LOCKED OUT OF HOUSE SO PUNCHED A GL...
# 741     33YOM PUNCHED A WALL X1 WEEK AGO W/ SHARP PAIN...
# 778           FRACTURED HAND 27 YO M PUNCHED DOOR AT HOME
# 782                  28YOM PUNCHED A WALL AND INJ RT HAND
# 947     15YOM PUNCHED A LOCKER AT SCHOOL WHEN ANGRY WI...
# 1015    22YOM PUNCHED A GLASS LAMP IN EMOTIONAL OUTBUR...
# 1098                               25 YOF PUNCHED A WALL.
# 1571        14YOM SUST FX TO HAND WHEN HE PUNCHED A WALL*
# 1616       16 YOM CONTUSION TO HAND AFTER PUNCHING A WALL
# 1660           52 YOM PUNCHED WALL L HAND  DX:  FX 5TH MC
# 1707    20 YOF PUNCHED A WALL SEVERAL WEEKS AGO. NOW H...
# 2064    26 YOM PUNCHED WALL WITH BOTH HANDS DX CLINCHE...
# 2527    67YOM PUNCHED TABLE W/ RT HAND. PAINFUL/SWOLLE...
# 2669    22YOF PUNCHED A WALL WITH RIGHT HAND, RIGHT HA...
# 2714               13 YOM PUNCHED A WALL AND INJURED HAND
# 2777    10 YOM STATES PUNCHED SOMETHING HE THOUGHT WAS...
# 2953    24 YOM INJURED HAND, PUNCHED A WALL AT HOME. D...
# 3038    21YOF PUNCHED CABINET OUT OF ANGER, NOW WITH W...
# 3126    17 YOM GOT ANGRY & PUNCHED A WALL WITH HIS RT....
# 3150    18YOF C/O R HADN PAIN AFTER PUNCHING A BRICK W...
# 3260    21 YO M, C/O NOTICING DEFORMITY TO RT HAND S/P...
# 3714    20 YO FEMALE HURT PUNCHING A WALL AT UNSPECIFI...
# ...                                                   ...
# 294900  14 YOF- CONTUSION RT HAND - PT GOT ANGRY AND D...
# 300877  20 YO F, C/O RT 5TH FINGER PAIN S/P PUNCHING A...
# 301126  28 YOM DX HAND LACERATION/ETOH INTOXICATION - ...
# 305468  CONT. & DEVIATED SEPTUM 2ND TRAUMA: 20YOM BOXI...
# 306924  22YOM WAS TALKING TO GIRLFRIEND ON TELEPHONE, ...
# 307102  26 YO F,ANXIOUS EARLIER TODAY TRYING TO TAKE S...
# 307147  17 YOM HAD A FIGHT WITH BROTHER, MOM TOLD HIM ...
# 312376  20 YO M, C/O 2 DAYS OF RT HAND PAIN WORSENING ...
# 316649  22YOM RIDING BICYCLE SLAMMED ON BRAKES TO AVOI...
# 317395  13 YOM ANGRY WITH A PEER WHO WAS TEASING HIM A...
# 319242  35 YO M PT WAS SMOKING SPICE MARIJUANA STARTED...
# 319770  40 YOF WENT TO A BOYFRIEND'S HOUSE AND SAW THE...
# 320023  15YOM- MALE PRESENTS  W/ SWELLING TO 4TH AND 5...
# 321756  12 YO F C/O NECK PAIN WAS JUMPED BY 2 GIRLS YE...
# 322976  41YOF SUST CONTUSION TO HAND AFTER SHE WAS DRI...
# 322983  25YOM SUST HAND FX WHEN HE HAD AN ARGUMENT WIT...
# 326175  35 YOM PRESENTS WITH HAND PAIN, SUSTAINED AT H...
# 327492  54YM ETOH/BAC0.270 INTOX'D INTIAL C/O CP, ALSO...
# 328904  44 YO M, GOT INTO ARGUMENT W/ GF AT HOME EARLI...
# 329009  24YOM PAIN TO NOSE WHEN BOXING WITH BROTHER WE...
# 335575  39YOM AT HOME SCREWING METAL PIPE WITH A WRENC...
# 336323  39YOM INTOXICATED. BLEEDING FROM RT SECOND DIG...
# 338631  33YOM W/SMOKE INHALATION & CO EXPOSURE 2/2 BEI...
# 342246  20YOM SUST NASAL FX WHEN HE WAS PARTICIPATING ...
# 343296  28 YOF STATES SHE DROPPED SOMETHING IN HER KIT...
# 343721  36 YOM DX CONTUSION OF HAND - S/P PT WITH PAIN...
# 347343  32 YOM DX FX OF OF THE HAMATE (WRIST)/DISLOCAT...
# 349363  14YOF- PT IS A RUN AWAY-PT SAY GOT HOME MOM PU...
# 355892  23YO M WITH DIZZINESS, VOMITING, BRIEF LOC AFT...
# 357620  14 YOM DX FX OF 5TH METACARPAL W/VOLAR DISPLAC...
#
#                                                     narr2
# 10                                                    NaN
# 38                                                >>CONTS
# 149                                                   NaN
# 246                                                   NaN
# 385                                                 RIST.
# 582                                                   NaN
# 604                                                   NaN
# 704                                 DX: CONTUSION OF HAND
# 707         IN THE HOUSE & INJURED ARM     DX  LACERATION
# 741     DX: ACUTE CLOSED FX OF FIFTH METACARPAL, BOXER...
# 778                                                   NaN
# 782                                                   NaN
# 947                                                   NaN
# 1015                                                  NaN
# 1098                                    DX:  R HAND CONT.
# 1571                                                  NaN
# 1616                                                  NaN
# 1660                                                  NaN
# 1707                PAINFUL SOMETIMES. DX LEFT THUMB PAIN
# 2064                                                  NaN
# 2527                                              ACARPAL
# 2669                                                  NaN
# 2714                                        DX   FRACTURE
# 2777             & CUT HAND   DX LACERATION TO RIGHT HAND
# 2953                                                 HAND
# 3038                                                  NaN
# 3126                      DX; RT 4TH METACARPAL CONTUSION
# 3150                                MPER DX: R HAND CONTU
# 3260                                       O DX HAND CONT
# 3714                                                    B
# ...                                                   ...
# 294900  WALL HURTING HAND. NURSES STATED PUNCH CLOSET ...
# 300877  WAS IN ARGUMENT GOT ANGRY PUNCHED DOOR, DX HAN...
# 301126                            PUNCHED A GLASS WINDOW.
# 305468                      PUNCHED SEVERAL TIMES IN NOSE
# 306924  HUNG UP AND PUNCHED A WALL. DX-CLOSED RT HAND ...
# 307102  IN BATHROOM GOT UPSET PUNCHED WINDOW W/ HAND A...
# 307147  OFF" - TRIED TO GET IN HOUSE, GOT MAD ,PUNCHED...
# 312376   A METAL GATE YESTERDAY PUNCHED A WALL DX HAND FX
# 316649  OFF THE BICYCLE PUNCHED HOOD OF CAR DX-SUPERFI...
# 317395  S WHEN HE PUNCHED A WINDOW IN ANGER DX LACERAT...
# 319242  PUNCHING WALLS, RT HAND PAINFUL DX CONTUSION R...
# 319770  EMALE.  THIS CAUSED HER TO PUNCH A WINDOW OF G...
# 320023  AFTER PUNCHING WALL DX- FRACTURES OF 4TH AND 5...
# 321756  RAGGED HER ON THE FLOOR KICKED/PUNCHED HER DX ...
# 322976                                    PUNCHED A WALL*
# 322983             A PUNCHING BAG WITHOUT WEARING GLOVES*
# 326175  G BASKETBALL AND PUNCHING WALL.  DX: CONTUSION...
# 327492                                PUNCHING A WALL>>FX
# 328904  N BATHROOM PUNCHED WALL +ABRASIONS RT HAND DX ...
# 329009                HER PUNCHED HIM IN NOSE. / NASAL FX
# 335575  PPED PT PUNCHED HOUSE DX R 5TH PHALANGE FRACTU...
# 336323  EITHER PUNCHED A MIRROR OR BROTHER. BAL=397. D...
# 338631  LACS TO HAND 2/2 PUNCHED THRU A WINDOW TO RESC...
# 342246             AND THE PUNCH WENT RIGHT FOR HIS NOSE*
# 343296  MAD AND PUNCHED A WALL, HAS PAIN TO RT SHOULDE...
# 343721                   AFTER PUNCHING A WALL WEEKS AGO.
# 347343  JOINT - S/P AFTER PUNCHING HIS FRIDGE 2 DAYS AGO.
# 349363  PULLED HAIR PT PUNCHED A WINDOW NOW ABRAISONS ...
# 355892  H 1.5 HOURS AGO AND PUNCHED & KNOCKED TO GROUN...
# 357620      PUNCHED THE LOCKER C/O PAIN TO RT 5TH FINGER.
#
# [3773 rows x 19 columns]

# %%
#view the top 10 products from field "prod1"
prod1_value_counts = df_objectpunchers_all.prod1.value_counts().sort_values(ascending=False)
prod1_value_counts.head(10)
# Out:
# 1884    1843
# 1894     587
# 1893     250
# 1207     172
# 4004     125
# 276       76
# 4057      54
# 1892      52
# 1726      44
# 1807      42
# Name: prod1, dtype: int64

# %%
#view the top 10 products from field "prod2"
prod2_value_counts = df_objectpunchers_all.prod2.value_counts().sort_values(ascending=False)
prod2_value_counts.head(10)
# Out:
# 1884.0    37
# 1893.0    14
# 1807.0     8
# 1207.0     7
# 4056.0     6
# 1892.0     6
# 1865.0     5
# 604.0      5
# 1819.0     3
# 676.0      3
# Name: prod2, dtype: int64

# %%
#Add the two value_counts
prod_total_value_counts = prod1_value_counts.add(prod2_value_counts, fill_value=0).sort_values(ascending=False)
prod_total_value_counts.head(10)
# Out:
# 1884.0    1880.0
# 1894.0     589.0
# 1893.0     264.0
# 1207.0     179.0
# 4004.0     127.0
# 276.0       76.0
# 1892.0      58.0
# 4057.0      54.0
# 1807.0      50.0
# 1726.0      44.0
# dtype: float64

# %% [markdown]
# ## Uh, they're the same!

# %% [markdown]
# The order of `prod1` and `prod2` don't actually matter!
#
# > When only one product is associated with an injury, place the product code for that product in the space allocated for "First Product Code" and fill in the "Second Product Code" spaces with 4 zeros (0000).
# When two products are associated with an injury, either product may be coded as the first product and the other as the second product.
# >
# > Example: An 11-year old boy riding a bicycle ran into a swing. Code: Product 1 = 5040 (bicycle) and Product 2 = 3246 (swings) or
# >
# > Code: Product 1 = 3246 (swings) and Product 2 = 5040 (bicycle)
#
# ## Okay, okay, there’s no difference between prod1 and prod2, so you should add their frequencies together for an overall count!
#
# It's *almost* as easy as adding together the `value_counts()`.
#
# Take a look at the air conditioner question and the `.value_counts()` you just did, though, to see why combining them might not be that simple. **What is different about `prod1` and `prod2`?** You probably have to go all the way back up to where you read the file in to make them match.

# %% [markdown]
# ## Turn that into a dataframe
#
# Use `.reset_index()` on the result to turn it into a dataframe. Rename your columns to be `product_code` and `injury_count`.

# %%
punchinginjuries = prod_total_value_counts.reset_index()
punchinginjuries.head()
# Out:
#     index       0
# 0  1884.0  1880.0
# 1  1894.0   589.0
# 2  1893.0   264.0
# 3  1207.0   179.0
# 4  4004.0   127.0

# %%
punch_columns = {
    'index': 'prod_id',
    0: 'incident_count'
}

# %%
punchinginjuries.rename(columns=punch_columns, inplace=True)

# %%
punchinginjuries.head()
# Out:
#    prod_id  incident_count
# 0   1884.0          1880.0
# 1   1894.0           589.0
# 2   1893.0           264.0
# 3   1207.0           179.0
# 4   4004.0           127.0

# %% [markdown]
# ## Fix the product codes
#
# Uh, wait, look at those product codes. "102" shouldn't be possible, it should be `0102` - this actually doesn't have to do with coding, it has to do with *the data doesn't match the codebook*.
#
# ### Add zeroes to the left of the product code until it is 4 characters long

# %%
punchinginjuries.prod_id = punchinginjuries.prod_id.astype(str).str.pad(6, fillchar="0").str.rstrip("0").str.rstrip(".")

# %%
punchinginjuries.head()
# Out:
#   prod_id  incident_count
# 0    1884          1880.0
# 1    1894           589.0
# 2    1893           264.0
# 3    1207           179.0
# 4    4004           127.0

# %% [markdown]
# ## Get meaningful names for "product code"
#
# Join with `categories-cleaned.txt` to turn the codes into actual words. **When you read in `categories-cleaned.txt`, make sure it has 803 rows and 2 columns.**

# %%
df_cat = pd.read_csv("categories-cleaned.txt", header=None, names=["prod_id", "prod_desc"], dtype=str)

# %%
df_cat.shape
# Out:
# (803, 2)

# %% [markdown]
# ### Confirm that it worked by seeing if product code '0102' gives you 'Wringer washing machines"

# %%
df_cat[df_cat.prod_id == "0102"]
# Out:
#   prod_id                 prod_desc
# 0    0102  Wringer washing machines

# %%
merged = punchinginjuries.merge(df_cat, left_on="prod_id", right_on="prod_id")

# %% [markdown]
# ## Graph the top 10 most popular products for injuries

# %%
merged.sort_values('incident_count', ascending=False).head(10).sort_values('incident_count').plot(x='prod_desc', y='incident_count', kind="barh", figsize=(8,5))
